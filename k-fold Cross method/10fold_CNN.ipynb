# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# === CONFIGURATION ===
IMAGE_SIZE = 256
BATCH_SIZE = 32
EPOCHS = 25
FOLDS = 10
DATASET_DIR = "CyAUG-Dataset"  # 👈 Folder containing class-named subfolders

# === STEP 1: Load all image paths and labels from folder structure ===
data = []
for class_name in os.listdir(DATASET_DIR):
    class_path = os.path.join(DATASET_DIR, class_name)
    if os.path.isdir(class_path):
        for img in os.listdir(class_path):
            if img.lower().endswith(('.jpg', '.jpeg', '.png')):
                data.append([os.path.join(class_path, img), class_name])

df = pd.DataFrame(data, columns=["filename", "class"])
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# === STEP 2: Label Encoding ===
label_map = {label: idx for idx, label in enumerate(sorted(df["class"].unique()))}
df["class_idx"] = df["class"].map(label_map)
NUM_CLASSES = len(label_map)

# === STEP 3: CNN Model ===
def build_cnn_model(input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3), num_classes=NUM_CLASSES):
    model = models.Sequential([
        layers.Input(shape=input_shape),

        layers.Conv2D(32, (3,3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2,2)),

        layers.Conv2D(64, (3,3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2,2)),

        layers.Conv2D(128, (3,3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2,2)),

        layers.GlobalAveragePooling2D(),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation='softmax')
    ])
    return model

# === STEP 4: Data Generator ===
datagen = ImageDataGenerator(rescale=1./255)

# === STEP 5: K-Fold Cross-Validation ===
skf = StratifiedKFold(n_splits=FOLDS, shuffle=True, random_state=42)
fold_accuracies = []
fold_histories = []

for fold, (train_idx, val_idx) in enumerate(skf.split(df["filename"], df["class_idx"])):
    print(f"\n🟦 Fold {fold+1}/{FOLDS}")

    train_df = df.iloc[train_idx]
    val_df = df.iloc[val_idx]

    train_gen = datagen.flow_from_dataframe(
        train_df,
        x_col="filename",
        y_col="class",
        target_size=(IMAGE_SIZE, IMAGE_SIZE),
        class_mode="categorical",
        batch_size=BATCH_SIZE,
        shuffle=True,
        seed=42
    )

    val_gen = datagen.flow_from_dataframe(
        val_df,
        x_col="filename",
        y_col="class",
        target_size=(IMAGE_SIZE, IMAGE_SIZE),
        class_mode="categorical",
        batch_size=BATCH_SIZE,
        shuffle=False
    )

    model = build_cnn_model()
    model.compile(optimizer=Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])

    early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    lr_reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3)

    history = model.fit(
        train_gen,
        validation_data=val_gen,
        epochs=EPOCHS,
        callbacks=[early_stop, lr_reduce],
        verbose=1
    )

    val_loss, val_acc = model.evaluate(val_gen, verbose=0)
    fold_histories.append(history.history)
    fold_accuracies.append(val_acc)
    print(f"✅ Fold {fold+1} Accuracy: {val_acc:.4f}")

# === STEP 6: Summary ===
mean_acc = np.mean(fold_accuracies)
std_acc = np.std(fold_accuracies)
print(f"\n📊 5-Fold Validation Accuracy: {mean_acc:.4f} ± {std_acc:.4f}")

# === STEP 7: Accuracy/Loss Plot ===
def plot_kfold_results(histories):
    fig, axs = plt.subplots(2, 1, figsize=(12, 10))

    for i, history in enumerate(histories):
        axs[0].plot(history['accuracy'], label=f'Train Fold {i+1}')
        axs[0].plot(history['val_accuracy'], linestyle='--', label=f'Val Fold {i+1}')
        axs[1].plot(history['loss'], label=f'Train Fold {i+1}')
        axs[1].plot(history['val_loss'], linestyle='--', label=f'Val Fold {i+1}')

    axs[0].set_title('Training vs Validation Accuracy (All Folds)')
    axs[0].set_ylabel('Accuracy')
    axs[0].legend()
    axs[0].grid()

    axs[1].set_title('Training vs Validation Loss (All Folds)')
    axs[1].set_ylabel('Loss')
    axs[1].legend()
    axs[1].grid()

    plt.tight_layout()
    plt.show()

plot_kfold_results(fold_histories)
# Out:
# 🟦 Fold 1/10
# Found 4586 validated image filenames belonging to 7 classes.
# Found 510 validated image filenames belonging to 7 classes.
# 2025-07-01 08:58:41.419924: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Max
# 2025-07-01 08:58:41.419963: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 32.00 GB
# 2025-07-01 08:58:41.419983: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 10.67 GB
# 2025-07-01 08:58:41.420003: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-07-01 08:58:41.420015: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# /Users/simarkalsi/Projects/Soil k-cross/soilk/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 2025-07-01 08:58:42.105322: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 17s 107ms/step - accuracy: 0.6501 - loss: 1.1536 - val_accuracy: 0.1373 - val_loss: 1.7915 - learning_rate: 1.0000e-04
# Epoch 2/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 97ms/step - accuracy: 0.8566 - loss: 0.4438 - val_accuracy: 0.5510 - val_loss: 1.2094 - learning_rate: 1.0000e-04
# Epoch 3/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step - accuracy: 0.8753 - loss: 0.3707 - val_accuracy: 0.8588 - val_loss: 0.4566 - learning_rate: 1.0000e-04
# Epoch 4/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 97ms/step - accuracy: 0.8952 - loss: 0.3032 - val_accuracy: 0.9216 - val_loss: 0.2477 - learning_rate: 1.0000e-04
# Epoch 5/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 97ms/step - accuracy: 0.8873 - loss: 0.3484 - val_accuracy: 0.9314 - val_loss: 0.2238 - learning_rate: 1.0000e-04
# Epoch 6/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - accuracy: 0.9045 - loss: 0.2996 - val_accuracy: 0.9196 - val_loss: 0.2221 - learning_rate: 1.0000e-04
# Epoch 7/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step - accuracy: 0.8994 - loss: 0.2923 - val_accuracy: 0.9373 - val_loss: 0.1956 - learning_rate: 1.0000e-04
# Epoch 8/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9166 - loss: 0.2613 - val_accuracy: 0.9059 - val_loss: 0.2483 - learning_rate: 1.0000e-04
# Epoch 9/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9112 - loss: 0.2664 - val_accuracy: 0.9392 - val_loss: 0.1943 - learning_rate: 1.0000e-04
# Epoch 10/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9195 - loss: 0.2548 - val_accuracy: 0.9373 - val_loss: 0.1695 - learning_rate: 1.0000e-04
# Epoch 11/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9089 - loss: 0.2745 - val_accuracy: 0.9118 - val_loss: 0.2321 - learning_rate: 1.0000e-04
# Epoch 12/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9188 - loss: 0.2521 - val_accuracy: 0.9353 - val_loss: 0.1939 - learning_rate: 1.0000e-04
# Epoch 13/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9186 - loss: 0.2488 - val_accuracy: 0.9333 - val_loss: 0.1904 - learning_rate: 1.0000e-04
# Epoch 14/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9200 - loss: 0.2487 - val_accuracy: 0.9353 - val_loss: 0.1699 - learning_rate: 5.0000e-05
# Epoch 15/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9292 - loss: 0.2169 - val_accuracy: 0.9431 - val_loss: 0.1786 - learning_rate: 5.0000e-05
# ✅ Fold 1 Accuracy: 0.9373
#
# 🟦 Fold 2/10
# Found 4586 validated image filenames belonging to 7 classes.
# Found 510 validated image filenames belonging to 7 classes.
# Epoch 1/25
# /Users/simarkalsi/Projects/Soil k-cross/soilk/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 15s 96ms/step - accuracy: 0.6804 - loss: 1.0211 - val_accuracy: 0.1510 - val_loss: 1.9193 - learning_rate: 1.0000e-04
# Epoch 2/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.8564 - loss: 0.4503 - val_accuracy: 0.3863 - val_loss: 1.4318 - learning_rate: 1.0000e-04
# Epoch 3/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step - accuracy: 0.8751 - loss: 0.3825 - val_accuracy: 0.7882 - val_loss: 0.6135 - learning_rate: 1.0000e-04
# Epoch 4/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - accuracy: 0.8962 - loss: 0.3282 - val_accuracy: 0.9039 - val_loss: 0.2863 - learning_rate: 1.0000e-04
# Epoch 5/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.8896 - loss: 0.3372 - val_accuracy: 0.9255 - val_loss: 0.2193 - learning_rate: 1.0000e-04
# Epoch 6/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - accuracy: 0.8928 - loss: 0.3080 - val_accuracy: 0.9314 - val_loss: 0.1966 - learning_rate: 1.0000e-04
# Epoch 7/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - accuracy: 0.8966 - loss: 0.2966 - val_accuracy: 0.9333 - val_loss: 0.1854 - learning_rate: 1.0000e-04
# Epoch 8/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - accuracy: 0.9116 - loss: 0.2691 - val_accuracy: 0.9471 - val_loss: 0.1634 - learning_rate: 1.0000e-04
# Epoch 9/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - accuracy: 0.9079 - loss: 0.2720 - val_accuracy: 0.9471 - val_loss: 0.1787 - learning_rate: 1.0000e-04
# Epoch 10/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.9123 - loss: 0.2702 - val_accuracy: 0.9529 - val_loss: 0.1490 - learning_rate: 1.0000e-04
# Epoch 11/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - accuracy: 0.9149 - loss: 0.2592 - val_accuracy: 0.9431 - val_loss: 0.1742 - learning_rate: 1.0000e-04
# Epoch 12/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 97ms/step - accuracy: 0.9209 - loss: 0.2510 - val_accuracy: 0.9471 - val_loss: 0.1794 - learning_rate: 1.0000e-04
# Epoch 13/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 97ms/step - accuracy: 0.9182 - loss: 0.2553 - val_accuracy: 0.9431 - val_loss: 0.1687 - learning_rate: 1.0000e-04
# Epoch 14/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9234 - loss: 0.2494 - val_accuracy: 0.9275 - val_loss: 0.1810 - learning_rate: 5.0000e-05
# Epoch 15/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9271 - loss: 0.2166 - val_accuracy: 0.9451 - val_loss: 0.1465 - learning_rate: 5.0000e-05
# Epoch 16/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9305 - loss: 0.2072 - val_accuracy: 0.9392 - val_loss: 0.1553 - learning_rate: 5.0000e-05
# Epoch 17/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9239 - loss: 0.2307 - val_accuracy: 0.9431 - val_loss: 0.1624 - learning_rate: 5.0000e-05
# Epoch 18/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9358 - loss: 0.1945 - val_accuracy: 0.9471 - val_loss: 0.1415 - learning_rate: 5.0000e-05
# Epoch 19/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9297 - loss: 0.1995 - val_accuracy: 0.9529 - val_loss: 0.1360 - learning_rate: 5.0000e-05
# Epoch 20/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9263 - loss: 0.2092 - val_accuracy: 0.9490 - val_loss: 0.1372 - learning_rate: 5.0000e-05
# Epoch 21/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9285 - loss: 0.2234 - val_accuracy: 0.9490 - val_loss: 0.1539 - learning_rate: 5.0000e-05
# Epoch 22/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9322 - loss: 0.2114 - val_accuracy: 0.9549 - val_loss: 0.1416 - learning_rate: 5.0000e-05
# Epoch 23/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9318 - loss: 0.1919 - val_accuracy: 0.9549 - val_loss: 0.1430 - learning_rate: 2.5000e-05
# Epoch 24/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9320 - loss: 0.2037 - val_accuracy: 0.9529 - val_loss: 0.1390 - learning_rate: 2.5000e-05
# ✅ Fold 2 Accuracy: 0.9529
#
# 🟦 Fold 3/10
# Found 4586 validated image filenames belonging to 7 classes.
# Found 510 validated image filenames belonging to 7 classes.
# Epoch 1/25
# /Users/simarkalsi/Projects/Soil k-cross/soilk/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 16s 99ms/step - accuracy: 0.6439 - loss: 1.1317 - val_accuracy: 0.2843 - val_loss: 1.7347 - learning_rate: 1.0000e-04
# Epoch 2/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - accuracy: 0.8401 - loss: 0.4590 - val_accuracy: 0.5137 - val_loss: 1.1681 - learning_rate: 1.0000e-04
# Epoch 3/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.8687 - loss: 0.3776 - val_accuracy: 0.8745 - val_loss: 0.4529 - learning_rate: 1.0000e-04
# Epoch 4/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.8714 - loss: 0.3790 - val_accuracy: 0.9118 - val_loss: 0.2806 - learning_rate: 1.0000e-04
# Epoch 5/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.8988 - loss: 0.3267 - val_accuracy: 0.9039 - val_loss: 0.3249 - learning_rate: 1.0000e-04
# Epoch 6/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.8931 - loss: 0.3215 - val_accuracy: 0.9314 - val_loss: 0.2169 - learning_rate: 1.0000e-04
# Epoch 7/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9086 - loss: 0.2938 - val_accuracy: 0.9314 - val_loss: 0.2215 - learning_rate: 1.0000e-04
# Epoch 8/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9001 - loss: 0.2876 - val_accuracy: 0.9176 - val_loss: 0.2831 - learning_rate: 1.0000e-04
# Epoch 9/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9049 - loss: 0.2653 - val_accuracy: 0.9471 - val_loss: 0.2049 - learning_rate: 1.0000e-04
# Epoch 10/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9042 - loss: 0.2838 - val_accuracy: 0.9353 - val_loss: 0.2064 - learning_rate: 1.0000e-04
# Epoch 11/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9083 - loss: 0.2607 - val_accuracy: 0.9353 - val_loss: 0.2129 - learning_rate: 1.0000e-04
# Epoch 12/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9049 - loss: 0.3002 - val_accuracy: 0.9373 - val_loss: 0.1939 - learning_rate: 1.0000e-04
# Epoch 13/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9106 - loss: 0.2584 - val_accuracy: 0.9373 - val_loss: 0.2207 - learning_rate: 1.0000e-04
# Epoch 14/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9093 - loss: 0.2661 - val_accuracy: 0.9510 - val_loss: 0.1811 - learning_rate: 1.0000e-04
# Epoch 15/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9154 - loss: 0.2567 - val_accuracy: 0.9392 - val_loss: 0.2216 - learning_rate: 1.0000e-04
# Epoch 16/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9124 - loss: 0.2718 - val_accuracy: 0.9431 - val_loss: 0.1930 - learning_rate: 1.0000e-04
# Epoch 17/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9174 - loss: 0.2334 - val_accuracy: 0.9392 - val_loss: 0.2287 - learning_rate: 1.0000e-04
# Epoch 18/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9283 - loss: 0.2276 - val_accuracy: 0.9510 - val_loss: 0.1720 - learning_rate: 5.0000e-05
# Epoch 19/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9216 - loss: 0.2146 - val_accuracy: 0.9451 - val_loss: 0.1889 - learning_rate: 5.0000e-05
# Epoch 20/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9291 - loss: 0.2109 - val_accuracy: 0.9431 - val_loss: 0.1790 - learning_rate: 5.0000e-05
# Epoch 21/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9266 - loss: 0.2137 - val_accuracy: 0.9510 - val_loss: 0.1746 - learning_rate: 5.0000e-05
# Epoch 22/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9328 - loss: 0.2131 - val_accuracy: 0.9510 - val_loss: 0.1681 - learning_rate: 2.5000e-05
# Epoch 23/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9336 - loss: 0.1915 - val_accuracy: 0.9549 - val_loss: 0.1697 - learning_rate: 2.5000e-05
# Epoch 24/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9353 - loss: 0.2061 - val_accuracy: 0.9471 - val_loss: 0.1636 - learning_rate: 2.5000e-05
# Epoch 25/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9341 - loss: 0.1937 - val_accuracy: 0.9569 - val_loss: 0.1655 - learning_rate: 2.5000e-05
# ✅ Fold 3 Accuracy: 0.9471
#
# 🟦 Fold 4/10
# Found 4586 validated image filenames belonging to 7 classes.
# Found 510 validated image filenames belonging to 7 classes.
# Epoch 1/25
# /Users/simarkalsi/Projects/Soil k-cross/soilk/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 16s 97ms/step - accuracy: 0.6055 - loss: 1.3779 - val_accuracy: 0.1373 - val_loss: 1.7295 - learning_rate: 1.0000e-04
# Epoch 2/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.8420 - loss: 0.4734 - val_accuracy: 0.5647 - val_loss: 1.1038 - learning_rate: 1.0000e-04
# Epoch 3/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.8587 - loss: 0.4299 - val_accuracy: 0.8882 - val_loss: 0.4256 - learning_rate: 1.0000e-04
# Epoch 4/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.8842 - loss: 0.3538 - val_accuracy: 0.9255 - val_loss: 0.2257 - learning_rate: 1.0000e-04
# Epoch 5/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.8902 - loss: 0.3279 - val_accuracy: 0.9392 - val_loss: 0.2033 - learning_rate: 1.0000e-04
# Epoch 6/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.8996 - loss: 0.2976 - val_accuracy: 0.9294 - val_loss: 0.2339 - learning_rate: 1.0000e-04
# Epoch 7/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.8894 - loss: 0.3191 - val_accuracy: 0.9314 - val_loss: 0.2172 - learning_rate: 1.0000e-04
# Epoch 8/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9026 - loss: 0.2792 - val_accuracy: 0.9118 - val_loss: 0.2570 - learning_rate: 1.0000e-04
# Epoch 9/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 13s 94ms/step - accuracy: 0.9062 - loss: 0.2827 - val_accuracy: 0.9451 - val_loss: 0.1814 - learning_rate: 5.0000e-05
# Epoch 10/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9197 - loss: 0.2435 - val_accuracy: 0.9392 - val_loss: 0.1813 - learning_rate: 5.0000e-05
# Epoch 11/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9141 - loss: 0.2544 - val_accuracy: 0.9373 - val_loss: 0.1846 - learning_rate: 5.0000e-05
# Epoch 12/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9138 - loss: 0.2502 - val_accuracy: 0.9333 - val_loss: 0.1876 - learning_rate: 5.0000e-05
# Epoch 13/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9159 - loss: 0.2578 - val_accuracy: 0.9392 - val_loss: 0.1803 - learning_rate: 2.5000e-05
# Epoch 14/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 13s 93ms/step - accuracy: 0.9222 - loss: 0.2295 - val_accuracy: 0.9471 - val_loss: 0.1741 - learning_rate: 2.5000e-05
# Epoch 15/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9145 - loss: 0.2572 - val_accuracy: 0.9431 - val_loss: 0.1768 - learning_rate: 2.5000e-05
# Epoch 16/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9252 - loss: 0.2215 - val_accuracy: 0.9412 - val_loss: 0.1828 - learning_rate: 2.5000e-05
# Epoch 17/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9219 - loss: 0.2388 - val_accuracy: 0.9451 - val_loss: 0.1668 - learning_rate: 2.5000e-05
# Epoch 18/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9200 - loss: 0.2305 - val_accuracy: 0.9451 - val_loss: 0.1688 - learning_rate: 2.5000e-05
# Epoch 19/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9230 - loss: 0.2246 - val_accuracy: 0.9431 - val_loss: 0.1658 - learning_rate: 2.5000e-05
# Epoch 20/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9259 - loss: 0.2215 - val_accuracy: 0.9510 - val_loss: 0.1638 - learning_rate: 2.5000e-05
# Epoch 21/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9112 - loss: 0.2497 - val_accuracy: 0.9490 - val_loss: 0.1636 - learning_rate: 2.5000e-05
# Epoch 22/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9213 - loss: 0.2368 - val_accuracy: 0.9471 - val_loss: 0.1672 - learning_rate: 2.5000e-05
# Epoch 23/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9247 - loss: 0.2206 - val_accuracy: 0.9549 - val_loss: 0.1594 - learning_rate: 2.5000e-05
# Epoch 24/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9318 - loss: 0.2126 - val_accuracy: 0.9471 - val_loss: 0.1628 - learning_rate: 2.5000e-05
# Epoch 25/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9271 - loss: 0.2121 - val_accuracy: 0.9431 - val_loss: 0.1630 - learning_rate: 2.5000e-05
# ✅ Fold 4 Accuracy: 0.9549
#
# 🟦 Fold 5/10
# Found 4586 validated image filenames belonging to 7 classes.
# Found 510 validated image filenames belonging to 7 classes.
# Epoch 1/25
# /Users/simarkalsi/Projects/Soil k-cross/soilk/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 16s 98ms/step - accuracy: 0.6160 - loss: 1.3419 - val_accuracy: 0.6078 - val_loss: 1.5966 - learning_rate: 1.0000e-04
# Epoch 2/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.8566 - loss: 0.4814 - val_accuracy: 0.7471 - val_loss: 0.9621 - learning_rate: 1.0000e-04
# Epoch 3/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.8688 - loss: 0.4274 - val_accuracy: 0.8529 - val_loss: 0.4481 - learning_rate: 1.0000e-04
# Epoch 4/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.8817 - loss: 0.3568 - val_accuracy: 0.9059 - val_loss: 0.2568 - learning_rate: 1.0000e-04
# Epoch 5/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.8832 - loss: 0.3520 - val_accuracy: 0.9157 - val_loss: 0.2053 - learning_rate: 1.0000e-04
# Epoch 6/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.8859 - loss: 0.3508 - val_accuracy: 0.9255 - val_loss: 0.2188 - learning_rate: 1.0000e-04
# Epoch 7/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.8957 - loss: 0.3191 - val_accuracy: 0.9176 - val_loss: 0.2147 - learning_rate: 1.0000e-04
# Epoch 8/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9001 - loss: 0.3217 - val_accuracy: 0.9235 - val_loss: 0.2174 - learning_rate: 1.0000e-04
# Epoch 9/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9020 - loss: 0.3232 - val_accuracy: 0.9275 - val_loss: 0.1777 - learning_rate: 5.0000e-05
# Epoch 10/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9101 - loss: 0.2904 - val_accuracy: 0.9314 - val_loss: 0.1698 - learning_rate: 5.0000e-05
# Epoch 11/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9058 - loss: 0.2805 - val_accuracy: 0.9294 - val_loss: 0.1846 - learning_rate: 5.0000e-05
# Epoch 12/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9014 - loss: 0.2905 - val_accuracy: 0.9431 - val_loss: 0.1698 - learning_rate: 5.0000e-05
# Epoch 13/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9078 - loss: 0.2972 - val_accuracy: 0.9294 - val_loss: 0.1616 - learning_rate: 5.0000e-05
# Epoch 14/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9099 - loss: 0.2770 - val_accuracy: 0.9412 - val_loss: 0.1663 - learning_rate: 5.0000e-05
# Epoch 15/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9036 - loss: 0.2973 - val_accuracy: 0.9314 - val_loss: 0.1720 - learning_rate: 5.0000e-05
# Epoch 16/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9223 - loss: 0.2564 - val_accuracy: 0.9431 - val_loss: 0.1803 - learning_rate: 5.0000e-05
# Epoch 17/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9234 - loss: 0.2370 - val_accuracy: 0.9314 - val_loss: 0.1715 - learning_rate: 2.5000e-05
# Epoch 18/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9253 - loss: 0.2374 - val_accuracy: 0.9451 - val_loss: 0.1523 - learning_rate: 2.5000e-05
# Epoch 19/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9177 - loss: 0.2536 - val_accuracy: 0.9412 - val_loss: 0.1609 - learning_rate: 2.5000e-05
# Epoch 20/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9163 - loss: 0.2594 - val_accuracy: 0.9353 - val_loss: 0.1729 - learning_rate: 2.5000e-05
# Epoch 21/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9286 - loss: 0.2249 - val_accuracy: 0.9392 - val_loss: 0.1661 - learning_rate: 2.5000e-05
# Epoch 22/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9281 - loss: 0.2284 - val_accuracy: 0.9373 - val_loss: 0.1493 - learning_rate: 1.2500e-05
# Epoch 23/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9253 - loss: 0.2222 - val_accuracy: 0.9431 - val_loss: 0.1509 - learning_rate: 1.2500e-05
# Epoch 24/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9331 - loss: 0.2216 - val_accuracy: 0.9490 - val_loss: 0.1598 - learning_rate: 1.2500e-05
# Epoch 25/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9221 - loss: 0.2326 - val_accuracy: 0.9451 - val_loss: 0.1602 - learning_rate: 1.2500e-05
# ✅ Fold 5 Accuracy: 0.9373
#
# 🟦 Fold 6/10
# Found 4586 validated image filenames belonging to 7 classes.
# Found 510 validated image filenames belonging to 7 classes.
# Epoch 1/25
# /Users/simarkalsi/Projects/Soil k-cross/soilk/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 16s 99ms/step - accuracy: 0.6329 - loss: 1.1723 - val_accuracy: 0.1608 - val_loss: 1.7940 - learning_rate: 1.0000e-04
# Epoch 2/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.8456 - loss: 0.4695 - val_accuracy: 0.5902 - val_loss: 1.1066 - learning_rate: 1.0000e-04
# Epoch 3/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.8752 - loss: 0.3917 - val_accuracy: 0.8667 - val_loss: 0.4263 - learning_rate: 1.0000e-04
# Epoch 4/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.8813 - loss: 0.3507 - val_accuracy: 0.8961 - val_loss: 0.2825 - learning_rate: 1.0000e-04
# Epoch 5/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.8830 - loss: 0.3506 - val_accuracy: 0.9275 - val_loss: 0.2065 - learning_rate: 1.0000e-04
# Epoch 6/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.8848 - loss: 0.3341 - val_accuracy: 0.9314 - val_loss: 0.2033 - learning_rate: 1.0000e-04
# Epoch 7/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9010 - loss: 0.2899 - val_accuracy: 0.9294 - val_loss: 0.2317 - learning_rate: 1.0000e-04
# Epoch 8/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9080 - loss: 0.2958 - val_accuracy: 0.9137 - val_loss: 0.2197 - learning_rate: 1.0000e-04
# Epoch 9/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.8940 - loss: 0.3232 - val_accuracy: 0.9196 - val_loss: 0.2238 - learning_rate: 1.0000e-04
# Epoch 10/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9121 - loss: 0.2708 - val_accuracy: 0.9333 - val_loss: 0.1754 - learning_rate: 5.0000e-05
# Epoch 11/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9183 - loss: 0.2451 - val_accuracy: 0.9392 - val_loss: 0.1697 - learning_rate: 5.0000e-05
# Epoch 12/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9050 - loss: 0.2885 - val_accuracy: 0.9373 - val_loss: 0.1738 - learning_rate: 5.0000e-05
# Epoch 13/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9090 - loss: 0.2637 - val_accuracy: 0.9392 - val_loss: 0.1713 - learning_rate: 5.0000e-05
# Epoch 14/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9212 - loss: 0.2322 - val_accuracy: 0.9431 - val_loss: 0.1635 - learning_rate: 5.0000e-05
# Epoch 15/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9119 - loss: 0.2543 - val_accuracy: 0.9392 - val_loss: 0.1641 - learning_rate: 5.0000e-05
# Epoch 16/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9129 - loss: 0.2633 - val_accuracy: 0.9431 - val_loss: 0.1588 - learning_rate: 5.0000e-05
# Epoch 17/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9209 - loss: 0.2439 - val_accuracy: 0.9431 - val_loss: 0.1584 - learning_rate: 5.0000e-05
# Epoch 18/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9177 - loss: 0.2571 - val_accuracy: 0.9373 - val_loss: 0.1747 - learning_rate: 5.0000e-05
# Epoch 19/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9248 - loss: 0.2141 - val_accuracy: 0.9412 - val_loss: 0.1715 - learning_rate: 5.0000e-05
# Epoch 20/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9279 - loss: 0.2196 - val_accuracy: 0.9431 - val_loss: 0.1642 - learning_rate: 5.0000e-05
# Epoch 21/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9251 - loss: 0.2130 - val_accuracy: 0.9373 - val_loss: 0.1496 - learning_rate: 2.5000e-05
# Epoch 22/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9219 - loss: 0.2342 - val_accuracy: 0.9392 - val_loss: 0.1480 - learning_rate: 2.5000e-05
# Epoch 23/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9290 - loss: 0.2207 - val_accuracy: 0.9490 - val_loss: 0.1471 - learning_rate: 2.5000e-05
# Epoch 24/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9291 - loss: 0.1986 - val_accuracy: 0.9510 - val_loss: 0.1437 - learning_rate: 2.5000e-05
# Epoch 25/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9293 - loss: 0.2101 - val_accuracy: 0.9471 - val_loss: 0.1414 - learning_rate: 2.5000e-05
# ✅ Fold 6 Accuracy: 0.9471
#
# 🟦 Fold 7/10
# Found 4587 validated image filenames belonging to 7 classes.
# Found 509 validated image filenames belonging to 7 classes.
# Epoch 1/25
# /Users/simarkalsi/Projects/Soil k-cross/soilk/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 17s 104ms/step - accuracy: 0.6793 - loss: 1.0576 - val_accuracy: 0.1356 - val_loss: 1.9908 - learning_rate: 1.0000e-04
# Epoch 2/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.8735 - loss: 0.4064 - val_accuracy: 0.4145 - val_loss: 1.4772 - learning_rate: 1.0000e-04
# Epoch 3/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.8791 - loss: 0.3558 - val_accuracy: 0.7682 - val_loss: 0.6655 - learning_rate: 1.0000e-04
# Epoch 4/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.8895 - loss: 0.3217 - val_accuracy: 0.8959 - val_loss: 0.2873 - learning_rate: 1.0000e-04
# Epoch 5/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9009 - loss: 0.3061 - val_accuracy: 0.8900 - val_loss: 0.3092 - learning_rate: 1.0000e-04
# Epoch 6/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9014 - loss: 0.2963 - val_accuracy: 0.8919 - val_loss: 0.2809 - learning_rate: 1.0000e-04
# Epoch 7/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.8972 - loss: 0.3193 - val_accuracy: 0.9116 - val_loss: 0.2483 - learning_rate: 1.0000e-04
# Epoch 8/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9066 - loss: 0.2749 - val_accuracy: 0.9096 - val_loss: 0.2273 - learning_rate: 1.0000e-04
# Epoch 9/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9054 - loss: 0.2701 - val_accuracy: 0.9136 - val_loss: 0.2203 - learning_rate: 1.0000e-04
# Epoch 10/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9129 - loss: 0.2597 - val_accuracy: 0.9214 - val_loss: 0.2012 - learning_rate: 1.0000e-04
# Epoch 11/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 13s 93ms/step - accuracy: 0.9242 - loss: 0.2421 - val_accuracy: 0.9312 - val_loss: 0.1807 - learning_rate: 1.0000e-04
# Epoch 12/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9199 - loss: 0.2369 - val_accuracy: 0.9136 - val_loss: 0.2083 - learning_rate: 1.0000e-04
# Epoch 13/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9274 - loss: 0.2214 - val_accuracy: 0.9352 - val_loss: 0.1679 - learning_rate: 1.0000e-04
# Epoch 14/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9248 - loss: 0.2214 - val_accuracy: 0.9096 - val_loss: 0.2634 - learning_rate: 1.0000e-04
# Epoch 15/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9243 - loss: 0.2350 - val_accuracy: 0.9155 - val_loss: 0.2207 - learning_rate: 1.0000e-04
# Epoch 16/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9256 - loss: 0.2276 - val_accuracy: 0.9450 - val_loss: 0.1787 - learning_rate: 1.0000e-04
# Epoch 17/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9250 - loss: 0.2093 - val_accuracy: 0.9293 - val_loss: 0.2074 - learning_rate: 5.0000e-05
# Epoch 18/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9379 - loss: 0.1899 - val_accuracy: 0.9293 - val_loss: 0.1958 - learning_rate: 5.0000e-05
# ✅ Fold 7 Accuracy: 0.9352
#
# 🟦 Fold 8/10
# Found 4587 validated image filenames belonging to 7 classes.
# Found 509 validated image filenames belonging to 7 classes.
# Epoch 1/25
# /Users/simarkalsi/Projects/Soil k-cross/soilk/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 17s 102ms/step - accuracy: 0.6432 - loss: 1.1381 - val_accuracy: 0.1807 - val_loss: 1.6189 - learning_rate: 1.0000e-04
# Epoch 2/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.8474 - loss: 0.4720 - val_accuracy: 0.3713 - val_loss: 1.2198 - learning_rate: 1.0000e-04
# Epoch 3/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.8800 - loss: 0.3755 - val_accuracy: 0.8743 - val_loss: 0.4478 - learning_rate: 1.0000e-04
# Epoch 4/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.8944 - loss: 0.3215 - val_accuracy: 0.8998 - val_loss: 0.2716 - learning_rate: 1.0000e-04
# Epoch 5/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - accuracy: 0.8897 - loss: 0.3371 - val_accuracy: 0.9253 - val_loss: 0.2010 - learning_rate: 1.0000e-04
# Epoch 6/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - accuracy: 0.8955 - loss: 0.3080 - val_accuracy: 0.9293 - val_loss: 0.2058 - learning_rate: 1.0000e-04
# Epoch 7/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.9033 - loss: 0.3018 - val_accuracy: 0.9371 - val_loss: 0.1937 - learning_rate: 1.0000e-04
# Epoch 8/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - accuracy: 0.9051 - loss: 0.2821 - val_accuracy: 0.9352 - val_loss: 0.1637 - learning_rate: 1.0000e-04
# Epoch 9/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - accuracy: 0.9099 - loss: 0.2922 - val_accuracy: 0.9312 - val_loss: 0.1801 - learning_rate: 1.0000e-04
# Epoch 10/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.9158 - loss: 0.2562 - val_accuracy: 0.9214 - val_loss: 0.2225 - learning_rate: 1.0000e-04
# Epoch 11/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - accuracy: 0.9096 - loss: 0.2787 - val_accuracy: 0.9371 - val_loss: 0.1782 - learning_rate: 1.0000e-04
# Epoch 12/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.9215 - loss: 0.2532 - val_accuracy: 0.9528 - val_loss: 0.1410 - learning_rate: 5.0000e-05
# Epoch 13/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.9225 - loss: 0.2290 - val_accuracy: 0.9352 - val_loss: 0.1706 - learning_rate: 5.0000e-05
# Epoch 14/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.9179 - loss: 0.2413 - val_accuracy: 0.9450 - val_loss: 0.1401 - learning_rate: 5.0000e-05
# Epoch 15/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - accuracy: 0.9173 - loss: 0.2554 - val_accuracy: 0.9470 - val_loss: 0.1299 - learning_rate: 5.0000e-05
# Epoch 16/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - accuracy: 0.9304 - loss: 0.2201 - val_accuracy: 0.9509 - val_loss: 0.1285 - learning_rate: 5.0000e-05
# Epoch 17/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.9277 - loss: 0.2250 - val_accuracy: 0.9430 - val_loss: 0.1451 - learning_rate: 5.0000e-05
# Epoch 18/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - accuracy: 0.9249 - loss: 0.2175 - val_accuracy: 0.9489 - val_loss: 0.1297 - learning_rate: 5.0000e-05
# Epoch 19/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.9195 - loss: 0.2267 - val_accuracy: 0.9548 - val_loss: 0.1267 - learning_rate: 5.0000e-05
# Epoch 20/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.9320 - loss: 0.2147 - val_accuracy: 0.9528 - val_loss: 0.1321 - learning_rate: 5.0000e-05
# Epoch 21/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - accuracy: 0.9252 - loss: 0.2121 - val_accuracy: 0.9470 - val_loss: 0.1232 - learning_rate: 5.0000e-05
# Epoch 22/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.9279 - loss: 0.2075 - val_accuracy: 0.9509 - val_loss: 0.1304 - learning_rate: 5.0000e-05
# Epoch 23/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - accuracy: 0.9410 - loss: 0.1797 - val_accuracy: 0.9430 - val_loss: 0.1368 - learning_rate: 5.0000e-05
# Epoch 24/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.9275 - loss: 0.2068 - val_accuracy: 0.9450 - val_loss: 0.1465 - learning_rate: 5.0000e-05
# Epoch 25/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.9413 - loss: 0.1861 - val_accuracy: 0.9450 - val_loss: 0.1381 - learning_rate: 2.5000e-05
# ✅ Fold 8 Accuracy: 0.9470
#
# 🟦 Fold 9/10
# Found 4587 validated image filenames belonging to 7 classes.
# Found 509 validated image filenames belonging to 7 classes.
# Epoch 1/25
# /Users/simarkalsi/Projects/Soil k-cross/soilk/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 16s 98ms/step - accuracy: 0.6601 - loss: 1.0634 - val_accuracy: 0.1356 - val_loss: 2.0083 - learning_rate: 1.0000e-04
# Epoch 2/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.8691 - loss: 0.4044 - val_accuracy: 0.1827 - val_loss: 1.6106 - learning_rate: 1.0000e-04
# Epoch 3/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.8826 - loss: 0.3534 - val_accuracy: 0.8153 - val_loss: 0.6257 - learning_rate: 1.0000e-04
# Epoch 4/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 13s 93ms/step - accuracy: 0.8981 - loss: 0.3156 - val_accuracy: 0.8900 - val_loss: 0.3007 - learning_rate: 1.0000e-04
# Epoch 5/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9101 - loss: 0.2847 - val_accuracy: 0.9194 - val_loss: 0.2399 - learning_rate: 1.0000e-04
# Epoch 6/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9036 - loss: 0.2925 - val_accuracy: 0.9352 - val_loss: 0.1997 - learning_rate: 1.0000e-04
# Epoch 7/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9000 - loss: 0.2845 - val_accuracy: 0.9234 - val_loss: 0.2040 - learning_rate: 1.0000e-04
# Epoch 8/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9079 - loss: 0.2698 - val_accuracy: 0.9332 - val_loss: 0.2128 - learning_rate: 1.0000e-04
# Epoch 9/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9201 - loss: 0.2276 - val_accuracy: 0.9293 - val_loss: 0.1791 - learning_rate: 1.0000e-04
# Epoch 10/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9186 - loss: 0.2345 - val_accuracy: 0.9155 - val_loss: 0.2380 - learning_rate: 1.0000e-04
# Epoch 11/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9238 - loss: 0.2270 - val_accuracy: 0.9411 - val_loss: 0.1907 - learning_rate: 1.0000e-04
# Epoch 12/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9158 - loss: 0.2491 - val_accuracy: 0.9273 - val_loss: 0.2254 - learning_rate: 1.0000e-04
# Epoch 13/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9276 - loss: 0.2248 - val_accuracy: 0.9411 - val_loss: 0.1678 - learning_rate: 5.0000e-05
# Epoch 14/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9318 - loss: 0.1952 - val_accuracy: 0.9391 - val_loss: 0.1767 - learning_rate: 5.0000e-05
# Epoch 15/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9235 - loss: 0.2219 - val_accuracy: 0.9411 - val_loss: 0.1605 - learning_rate: 5.0000e-05
# Epoch 16/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9349 - loss: 0.1957 - val_accuracy: 0.9391 - val_loss: 0.1789 - learning_rate: 5.0000e-05
# Epoch 17/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9367 - loss: 0.1880 - val_accuracy: 0.9371 - val_loss: 0.1854 - learning_rate: 5.0000e-05
# Epoch 18/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9433 - loss: 0.1702 - val_accuracy: 0.9450 - val_loss: 0.1733 - learning_rate: 5.0000e-05
# Epoch 19/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.9356 - loss: 0.1833 - val_accuracy: 0.9470 - val_loss: 0.1645 - learning_rate: 2.5000e-05
# Epoch 20/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9389 - loss: 0.1778 - val_accuracy: 0.9430 - val_loss: 0.1764 - learning_rate: 2.5000e-05
# ✅ Fold 9 Accuracy: 0.9411
#
# 🟦 Fold 10/10
# Found 4587 validated image filenames belonging to 7 classes.
# Found 509 validated image filenames belonging to 7 classes.
# Epoch 1/25
# /Users/simarkalsi/Projects/Soil k-cross/soilk/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 16s 102ms/step - accuracy: 0.6839 - loss: 0.9986 - val_accuracy: 0.1375 - val_loss: 2.1038 - learning_rate: 1.0000e-04
# Epoch 2/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.8472 - loss: 0.4670 - val_accuracy: 0.2338 - val_loss: 2.1425 - learning_rate: 1.0000e-04
# Epoch 3/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - accuracy: 0.8652 - loss: 0.4219 - val_accuracy: 0.6562 - val_loss: 0.8657 - learning_rate: 1.0000e-04
# Epoch 4/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.8759 - loss: 0.3804 - val_accuracy: 0.8802 - val_loss: 0.3267 - learning_rate: 1.0000e-04
# Epoch 5/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.8891 - loss: 0.3399 - val_accuracy: 0.9037 - val_loss: 0.2663 - learning_rate: 1.0000e-04
# Epoch 6/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.9022 - loss: 0.3034 - val_accuracy: 0.9371 - val_loss: 0.2147 - learning_rate: 1.0000e-04
# Epoch 7/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - accuracy: 0.9037 - loss: 0.2936 - val_accuracy: 0.9391 - val_loss: 0.1970 - learning_rate: 1.0000e-04
# Epoch 8/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.8985 - loss: 0.3002 - val_accuracy: 0.9234 - val_loss: 0.2554 - learning_rate: 1.0000e-04
# Epoch 9/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.8982 - loss: 0.2978 - val_accuracy: 0.9273 - val_loss: 0.1989 - learning_rate: 1.0000e-04
# Epoch 10/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.9141 - loss: 0.2550 - val_accuracy: 0.9450 - val_loss: 0.1507 - learning_rate: 1.0000e-04
# Epoch 11/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - accuracy: 0.9156 - loss: 0.2632 - val_accuracy: 0.9430 - val_loss: 0.1809 - learning_rate: 1.0000e-04
# Epoch 12/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.9082 - loss: 0.2661 - val_accuracy: 0.9371 - val_loss: 0.1756 - learning_rate: 1.0000e-04
# Epoch 13/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - accuracy: 0.9185 - loss: 0.2548 - val_accuracy: 0.9391 - val_loss: 0.1971 - learning_rate: 1.0000e-04
# Epoch 14/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.9239 - loss: 0.2348 - val_accuracy: 0.9568 - val_loss: 0.1569 - learning_rate: 5.0000e-05
# Epoch 15/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.9170 - loss: 0.2527 - val_accuracy: 0.9548 - val_loss: 0.1467 - learning_rate: 5.0000e-05
# Epoch 16/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.9252 - loss: 0.2314 - val_accuracy: 0.9548 - val_loss: 0.1341 - learning_rate: 5.0000e-05
# Epoch 17/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - accuracy: 0.9285 - loss: 0.2025 - val_accuracy: 0.9568 - val_loss: 0.1382 - learning_rate: 5.0000e-05
# Epoch 18/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - accuracy: 0.9222 - loss: 0.2398 - val_accuracy: 0.9528 - val_loss: 0.1433 - learning_rate: 5.0000e-05
# Epoch 19/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.9248 - loss: 0.2340 - val_accuracy: 0.9548 - val_loss: 0.1408 - learning_rate: 5.0000e-05
# Epoch 20/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.9257 - loss: 0.2180 - val_accuracy: 0.9587 - val_loss: 0.1284 - learning_rate: 2.5000e-05
# Epoch 21/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - accuracy: 0.9266 - loss: 0.2199 - val_accuracy: 0.9587 - val_loss: 0.1312 - learning_rate: 2.5000e-05
# Epoch 22/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - accuracy: 0.9358 - loss: 0.1967 - val_accuracy: 0.9548 - val_loss: 0.1316 - learning_rate: 2.5000e-05
# Epoch 23/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.9315 - loss: 0.2077 - val_accuracy: 0.9548 - val_loss: 0.1338 - learning_rate: 2.5000e-05
# Epoch 24/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.9262 - loss: 0.2121 - val_accuracy: 0.9568 - val_loss: 0.1277 - learning_rate: 1.2500e-05
# Epoch 25/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.9255 - loss: 0.2387 - val_accuracy: 0.9568 - val_loss: 0.1231 - learning_rate: 1.2500e-05
# ✅ Fold 10 Accuracy: 0.9568
#
# 📊 5-Fold Validation Accuracy: 0.9456 ± 0.0073

# %%
model.save(f"cnn_fold{fold+1}_CyAUG.keras")

# %%
import pickle
with open(f"history_fold{fold+1}_CyAUG.pkl", "wb") as f:
    pickle.dump(history.history, f)

# %%
def analyze_overfitting(histories):
    print("\n📉 Overfitting/Underfitting Analysis")
    for i, hist in enumerate(histories):
        acc = hist['accuracy']
        val_acc = hist['val_accuracy']
        loss = hist['loss']
        val_loss = hist['val_loss']
        
        acc_gap = val_acc[-1] - acc[-1]
        loss_gap = val_loss[-1] - loss[-1]

        print(f"Fold {i+1}:")
        if val_acc[-1] < acc[-1] - 0.05 and val_loss[-1] > loss[-1] + 0.2:
            print("  ⚠️  Likely Overfitting")
        elif val_acc[-1] < 0.7 and acc[-1] < 0.7:
            print("  🔍 Likely Underfitting")
        else:
            print("  ✅ Balanced Learning")
        print(f"  Final Acc: Train={acc[-1]:.4f}, Val={val_acc[-1]:.4f} | Loss: Train={loss[-1]:.4f}, Val={val_loss[-1]:.4f}")
        
analyze_overfitting(fold_histories)
# Out:
# 📉 Overfitting/Underfitting Analysis
# Fold 1:
#   ✅ Balanced Learning
#   Final Acc: Train=0.9287, Val=0.9431 | Loss: Train=0.2208, Val=0.1786
# Fold 2:
#   ✅ Balanced Learning
#   Final Acc: Train=0.9361, Val=0.9529 | Loss: Train=0.1909, Val=0.1390
# Fold 3:
#   ✅ Balanced Learning
#   Final Acc: Train=0.9302, Val=0.9569 | Loss: Train=0.1952, Val=0.1655
# Fold 4:
#   ✅ Balanced Learning
#   Final Acc: Train=0.9283, Val=0.9431 | Loss: Train=0.2144, Val=0.1630
# Fold 5:
#   ✅ Balanced Learning
#   Final Acc: Train=0.9193, Val=0.9451 | Loss: Train=0.2411, Val=0.1602
# Fold 6:
#   ✅ Balanced Learning
#   Final Acc: Train=0.9294, Val=0.9471 | Loss: Train=0.2078, Val=0.1414
# Fold 7:
#   ✅ Balanced Learning
#   Final Acc: Train=0.9348, Val=0.9293 | Loss: Train=0.1949, Val=0.1958
# Fold 8:
#   ✅ Balanced Learning
#   Final Acc: Train=0.9359, Val=0.9450 | Loss: Train=0.1928, Val=0.1381
# Fold 9:
#   ✅ Balanced Learning
#   Final Acc: Train=0.9387, Val=0.9430 | Loss: Train=0.1756, Val=0.1764
# Fold 10:
#   ✅ Balanced Learning
#   Final Acc: Train=0.9305, Val=0.9568 | Loss: Train=0.2186, Val=0.1231

# %%
def plot_accuracy_loss(histories):
    fig, axs = plt.subplots(1, 2, figsize=(14, 5))

    for i, history in enumerate(histories):
        axs[0].plot(history['accuracy'], label=f'Train Fold {i+1}')
        axs[0].plot(history['val_accuracy'], linestyle='--', label=f'Val Fold {i+1}')
        axs[1].plot(history['loss'], label=f'Train Fold {i+1}')
        axs[1].plot(history['val_loss'], linestyle='--', label=f'Val Fold {i+1}')

    axs[0].set_title('Training vs Validation Accuracy (All Folds)')
    axs[0].set_xlabel('Epochs')
    axs[0].set_ylabel('Accuracy')
    axs[0].legend()
    axs[0].grid(True)

    axs[1].set_title('Training vs Validation Loss (All Folds)')
    axs[1].set_xlabel('Epochs')
    axs[1].set_ylabel('Loss')
    axs[1].legend()
    axs[1].grid(True)

    plt.tight_layout()
    plt.show()

# ✅ Call this after training all folds
plot_accuracy_loss(fold_histories)
