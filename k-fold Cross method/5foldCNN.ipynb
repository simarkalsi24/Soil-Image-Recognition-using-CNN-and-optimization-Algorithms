# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# === CONFIGURATION ===
IMAGE_SIZE = 256
BATCH_SIZE = 32
EPOCHS = 25
FOLDS = 5
DATASET_DIR = "CyAUG-Dataset"  # 👈 Folder containing class-named subfolders

# === STEP 1: Load all image paths and labels from folder structure ===
data = []
for class_name in os.listdir(DATASET_DIR):
    class_path = os.path.join(DATASET_DIR, class_name)
    if os.path.isdir(class_path):
        for img in os.listdir(class_path):
            if img.lower().endswith(('.jpg', '.jpeg', '.png')):
                data.append([os.path.join(class_path, img), class_name])

df = pd.DataFrame(data, columns=["filename", "class"])
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# === STEP 2: Label Encoding ===
label_map = {label: idx for idx, label in enumerate(sorted(df["class"].unique()))}
df["class_idx"] = df["class"].map(label_map)
NUM_CLASSES = len(label_map)

# === STEP 3: CNN Model ===
def build_cnn_model(input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3), num_classes=NUM_CLASSES):
    model = models.Sequential([
        layers.Input(shape=input_shape),

        layers.Conv2D(32, (3,3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2,2)),

        layers.Conv2D(64, (3,3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2,2)),

        layers.Conv2D(128, (3,3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2,2)),

        layers.GlobalAveragePooling2D(),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation='softmax')
    ])
    return model

# === STEP 4: Data Generator ===
datagen = ImageDataGenerator(rescale=1./255)

# === STEP 5: K-Fold Cross-Validation ===
skf = StratifiedKFold(n_splits=FOLDS, shuffle=True, random_state=42)
fold_accuracies = []
fold_histories = []

for fold, (train_idx, val_idx) in enumerate(skf.split(df["filename"], df["class_idx"])):
    print(f"\n🟦 Fold {fold+1}/{FOLDS}")

    train_df = df.iloc[train_idx]
    val_df = df.iloc[val_idx]

    train_gen = datagen.flow_from_dataframe(
        train_df,
        x_col="filename",
        y_col="class",
        target_size=(IMAGE_SIZE, IMAGE_SIZE),
        class_mode="categorical",
        batch_size=BATCH_SIZE,
        shuffle=True,
        seed=42
    )

    val_gen = datagen.flow_from_dataframe(
        val_df,
        x_col="filename",
        y_col="class",
        target_size=(IMAGE_SIZE, IMAGE_SIZE),
        class_mode="categorical",
        batch_size=BATCH_SIZE,
        shuffle=False
    )

    model = build_cnn_model()
    model.compile(optimizer=Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])

    early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    lr_reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3)

    history = model.fit(
        train_gen,
        validation_data=val_gen,
        epochs=EPOCHS,
        callbacks=[early_stop, lr_reduce],
        verbose=1
    )

    val_loss, val_acc = model.evaluate(val_gen, verbose=0)
    fold_histories.append(history.history)
    fold_accuracies.append(val_acc)
    print(f"✅ Fold {fold+1} Accuracy: {val_acc:.4f}")

# === STEP 6: Summary ===
mean_acc = np.mean(fold_accuracies)
std_acc = np.std(fold_accuracies)
print(f"\n📊 5-Fold Validation Accuracy: {mean_acc:.4f} ± {std_acc:.4f}")

# === STEP 7: Accuracy/Loss Plot ===
def plot_kfold_results(histories):
    fig, axs = plt.subplots(2, 1, figsize=(12, 10))

    for i, history in enumerate(histories):
        axs[0].plot(history['accuracy'], label=f'Train Fold {i+1}')
        axs[0].plot(history['val_accuracy'], linestyle='--', label=f'Val Fold {i+1}')
        axs[1].plot(history['loss'], label=f'Train Fold {i+1}')
        axs[1].plot(history['val_loss'], linestyle='--', label=f'Val Fold {i+1}')

    axs[0].set_title('Training vs Validation Accuracy (All Folds)')
    axs[0].set_ylabel('Accuracy')
    axs[0].legend()
    axs[0].grid()

    axs[1].set_title('Training vs Validation Loss (All Folds)')
    axs[1].set_ylabel('Loss')
    axs[1].legend()
    axs[1].grid()

    plt.tight_layout()
    plt.show()

plot_kfold_results(fold_histories)
# Out:
# 🟦 Fold 1/5
# Found 4076 validated image filenames belonging to 7 classes.
# Found 1020 validated image filenames belonging to 7 classes.
# 2025-07-01 08:11:19.573839: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Max
# 2025-07-01 08:11:19.573884: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 32.00 GB
# 2025-07-01 08:11:19.573889: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 10.67 GB
# 2025-07-01 08:11:19.573929: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-07-01 08:11:19.573941: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# /Users/simarkalsi/Projects/Soil k-cross/soilk/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 2025-07-01 08:11:20.442832: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 16s 113ms/step - accuracy: 0.6304 - loss: 1.1837 - val_accuracy: 0.1363 - val_loss: 1.8161 - learning_rate: 1.0000e-04
# Epoch 2/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - accuracy: 0.8291 - loss: 0.5600 - val_accuracy: 0.4735 - val_loss: 1.2095 - learning_rate: 1.0000e-04
# Epoch 3/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - accuracy: 0.8636 - loss: 0.4365 - val_accuracy: 0.8461 - val_loss: 0.4944 - learning_rate: 1.0000e-04
# Epoch 4/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - accuracy: 0.8729 - loss: 0.3888 - val_accuracy: 0.8794 - val_loss: 0.3212 - learning_rate: 1.0000e-04
# Epoch 5/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - accuracy: 0.8846 - loss: 0.3710 - val_accuracy: 0.9118 - val_loss: 0.2481 - learning_rate: 1.0000e-04
# Epoch 6/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - accuracy: 0.8827 - loss: 0.3585 - val_accuracy: 0.9265 - val_loss: 0.2168 - learning_rate: 1.0000e-04
# Epoch 7/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - accuracy: 0.8898 - loss: 0.3458 - val_accuracy: 0.9196 - val_loss: 0.2278 - learning_rate: 1.0000e-04
# Epoch 8/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - accuracy: 0.9003 - loss: 0.3109 - val_accuracy: 0.9304 - val_loss: 0.2124 - learning_rate: 1.0000e-04
# Epoch 9/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - accuracy: 0.8958 - loss: 0.3153 - val_accuracy: 0.9186 - val_loss: 0.2471 - learning_rate: 1.0000e-04
# Epoch 10/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - accuracy: 0.9042 - loss: 0.2919 - val_accuracy: 0.9235 - val_loss: 0.2119 - learning_rate: 1.0000e-04
# Epoch 11/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - accuracy: 0.9075 - loss: 0.2841 - val_accuracy: 0.9294 - val_loss: 0.1973 - learning_rate: 1.0000e-04
# Epoch 12/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - accuracy: 0.9014 - loss: 0.3137 - val_accuracy: 0.9294 - val_loss: 0.1957 - learning_rate: 1.0000e-04
# Epoch 13/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - accuracy: 0.9142 - loss: 0.2695 - val_accuracy: 0.9304 - val_loss: 0.1958 - learning_rate: 1.0000e-04
# Epoch 14/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - accuracy: 0.9195 - loss: 0.2648 - val_accuracy: 0.9461 - val_loss: 0.1768 - learning_rate: 1.0000e-04
# Epoch 15/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - accuracy: 0.9164 - loss: 0.2546 - val_accuracy: 0.9412 - val_loss: 0.1657 - learning_rate: 1.0000e-04
# Epoch 16/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - accuracy: 0.9193 - loss: 0.2446 - val_accuracy: 0.9471 - val_loss: 0.1642 - learning_rate: 1.0000e-04
# Epoch 17/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - accuracy: 0.9154 - loss: 0.2439 - val_accuracy: 0.9275 - val_loss: 0.2136 - learning_rate: 1.0000e-04
# Epoch 18/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - accuracy: 0.9109 - loss: 0.2721 - val_accuracy: 0.9353 - val_loss: 0.1825 - learning_rate: 1.0000e-04
# Epoch 19/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - accuracy: 0.9221 - loss: 0.2252 - val_accuracy: 0.9520 - val_loss: 0.1496 - learning_rate: 1.0000e-04
# Epoch 20/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 100ms/step - accuracy: 0.9200 - loss: 0.2436 - val_accuracy: 0.9461 - val_loss: 0.1520 - learning_rate: 1.0000e-04
# Epoch 21/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 101ms/step - accuracy: 0.9273 - loss: 0.2311 - val_accuracy: 0.9373 - val_loss: 0.1821 - learning_rate: 1.0000e-04
# Epoch 22/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9268 - loss: 0.2345 - val_accuracy: 0.9520 - val_loss: 0.1381 - learning_rate: 1.0000e-04
# Epoch 23/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9175 - loss: 0.2435 - val_accuracy: 0.9451 - val_loss: 0.1593 - learning_rate: 1.0000e-04
# Epoch 24/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9245 - loss: 0.2143 - val_accuracy: 0.9441 - val_loss: 0.1559 - learning_rate: 1.0000e-04
# Epoch 25/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 106ms/step - accuracy: 0.9270 - loss: 0.2113 - val_accuracy: 0.9363 - val_loss: 0.1766 - learning_rate: 1.0000e-04
# ✅ Fold 1 Accuracy: 0.9520
#
# 🟦 Fold 2/5
# Found 4077 validated image filenames belonging to 7 classes.
# Found 1019 validated image filenames belonging to 7 classes.
# Epoch 1/25
# /Users/simarkalsi/Projects/Soil k-cross/soilk/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 15s 106ms/step - accuracy: 0.5794 - loss: 1.3764 - val_accuracy: 0.1354 - val_loss: 1.9009 - learning_rate: 1.0000e-04
# Epoch 2/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.8276 - loss: 0.5134 - val_accuracy: 0.1364 - val_loss: 2.3752 - learning_rate: 1.0000e-04
# Epoch 3/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.8592 - loss: 0.4093 - val_accuracy: 0.3072 - val_loss: 1.4234 - learning_rate: 1.0000e-04
# Epoch 4/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.8809 - loss: 0.3725 - val_accuracy: 0.7625 - val_loss: 0.6288 - learning_rate: 1.0000e-04
# Epoch 5/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.8846 - loss: 0.3504 - val_accuracy: 0.8999 - val_loss: 0.2811 - learning_rate: 1.0000e-04
# Epoch 6/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.8821 - loss: 0.3654 - val_accuracy: 0.9293 - val_loss: 0.2333 - learning_rate: 1.0000e-04
# Epoch 7/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.8988 - loss: 0.3241 - val_accuracy: 0.9382 - val_loss: 0.2017 - learning_rate: 1.0000e-04
# Epoch 8/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9006 - loss: 0.3147 - val_accuracy: 0.9450 - val_loss: 0.1963 - learning_rate: 1.0000e-04
# Epoch 9/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.8998 - loss: 0.3008 - val_accuracy: 0.9087 - val_loss: 0.2967 - learning_rate: 1.0000e-04
# Epoch 10/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.9063 - loss: 0.2812 - val_accuracy: 0.8862 - val_loss: 0.3280 - learning_rate: 1.0000e-04
# Epoch 11/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.9124 - loss: 0.2577 - val_accuracy: 0.9421 - val_loss: 0.2016 - learning_rate: 1.0000e-04
# Epoch 12/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.9242 - loss: 0.2390 - val_accuracy: 0.9460 - val_loss: 0.1836 - learning_rate: 5.0000e-05
# Epoch 13/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.9131 - loss: 0.2641 - val_accuracy: 0.9450 - val_loss: 0.1821 - learning_rate: 5.0000e-05
# Epoch 14/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.9148 - loss: 0.2504 - val_accuracy: 0.9401 - val_loss: 0.1888 - learning_rate: 5.0000e-05
# Epoch 15/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.9228 - loss: 0.2452 - val_accuracy: 0.9500 - val_loss: 0.1678 - learning_rate: 5.0000e-05
# Epoch 16/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.9198 - loss: 0.2388 - val_accuracy: 0.9529 - val_loss: 0.1739 - learning_rate: 5.0000e-05
# Epoch 17/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.9205 - loss: 0.2425 - val_accuracy: 0.9490 - val_loss: 0.1737 - learning_rate: 5.0000e-05
# Epoch 18/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9357 - loss: 0.2133 - val_accuracy: 0.9450 - val_loss: 0.1831 - learning_rate: 5.0000e-05
# Epoch 19/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.9255 - loss: 0.2270 - val_accuracy: 0.9470 - val_loss: 0.1771 - learning_rate: 2.5000e-05
# Epoch 20/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.9238 - loss: 0.2116 - val_accuracy: 0.9509 - val_loss: 0.1713 - learning_rate: 2.5000e-05
# ✅ Fold 2 Accuracy: 0.9500
#
# 🟦 Fold 3/5
# Found 4077 validated image filenames belonging to 7 classes.
# Found 1019 validated image filenames belonging to 7 classes.
# Epoch 1/25
# /Users/simarkalsi/Projects/Soil k-cross/soilk/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 15s 102ms/step - accuracy: 0.6662 - loss: 0.9972 - val_accuracy: 0.3023 - val_loss: 1.7825 - learning_rate: 1.0000e-04
# Epoch 2/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - accuracy: 0.8501 - loss: 0.4415 - val_accuracy: 0.5074 - val_loss: 1.3956 - learning_rate: 1.0000e-04
# Epoch 3/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - accuracy: 0.8816 - loss: 0.3621 - val_accuracy: 0.7920 - val_loss: 0.7029 - learning_rate: 1.0000e-04
# Epoch 4/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - accuracy: 0.8893 - loss: 0.3420 - val_accuracy: 0.8783 - val_loss: 0.3380 - learning_rate: 1.0000e-04
# Epoch 5/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - accuracy: 0.9015 - loss: 0.3008 - val_accuracy: 0.9185 - val_loss: 0.2342 - learning_rate: 1.0000e-04
# Epoch 6/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - accuracy: 0.9001 - loss: 0.2874 - val_accuracy: 0.9156 - val_loss: 0.2305 - learning_rate: 1.0000e-04
# Epoch 7/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - accuracy: 0.8932 - loss: 0.3179 - val_accuracy: 0.9313 - val_loss: 0.1946 - learning_rate: 1.0000e-04
# Epoch 8/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - accuracy: 0.8976 - loss: 0.3080 - val_accuracy: 0.9313 - val_loss: 0.1840 - learning_rate: 1.0000e-04
# Epoch 9/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - accuracy: 0.9157 - loss: 0.2546 - val_accuracy: 0.9372 - val_loss: 0.1882 - learning_rate: 1.0000e-04
# Epoch 10/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - accuracy: 0.9124 - loss: 0.2468 - val_accuracy: 0.9264 - val_loss: 0.1879 - learning_rate: 1.0000e-04
# Epoch 11/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 100ms/step - accuracy: 0.9112 - loss: 0.2813 - val_accuracy: 0.9372 - val_loss: 0.1747 - learning_rate: 1.0000e-04
# Epoch 12/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - accuracy: 0.9125 - loss: 0.2582 - val_accuracy: 0.9382 - val_loss: 0.1763 - learning_rate: 1.0000e-04
# Epoch 13/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - accuracy: 0.9185 - loss: 0.2313 - val_accuracy: 0.9431 - val_loss: 0.1520 - learning_rate: 1.0000e-04
# Epoch 14/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - accuracy: 0.9186 - loss: 0.2545 - val_accuracy: 0.9460 - val_loss: 0.1591 - learning_rate: 1.0000e-04
# Epoch 15/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - accuracy: 0.9225 - loss: 0.2249 - val_accuracy: 0.9382 - val_loss: 0.1577 - learning_rate: 1.0000e-04
# Epoch 16/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - accuracy: 0.9317 - loss: 0.1976 - val_accuracy: 0.9401 - val_loss: 0.1630 - learning_rate: 1.0000e-04
# Epoch 17/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - accuracy: 0.9309 - loss: 0.1997 - val_accuracy: 0.9421 - val_loss: 0.1499 - learning_rate: 5.0000e-05
# Epoch 18/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - accuracy: 0.9270 - loss: 0.2148 - val_accuracy: 0.9450 - val_loss: 0.1541 - learning_rate: 5.0000e-05
# Epoch 19/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - accuracy: 0.9312 - loss: 0.1904 - val_accuracy: 0.9431 - val_loss: 0.1733 - learning_rate: 5.0000e-05
# Epoch 20/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - accuracy: 0.9325 - loss: 0.1922 - val_accuracy: 0.9470 - val_loss: 0.1356 - learning_rate: 5.0000e-05
# Epoch 21/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - accuracy: 0.9302 - loss: 0.2051 - val_accuracy: 0.9470 - val_loss: 0.1583 - learning_rate: 5.0000e-05
# Epoch 22/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - accuracy: 0.9356 - loss: 0.1907 - val_accuracy: 0.9490 - val_loss: 0.1321 - learning_rate: 5.0000e-05
# Epoch 23/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - accuracy: 0.9338 - loss: 0.1897 - val_accuracy: 0.9431 - val_loss: 0.1469 - learning_rate: 5.0000e-05
# Epoch 24/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - accuracy: 0.9392 - loss: 0.1987 - val_accuracy: 0.9421 - val_loss: 0.1697 - learning_rate: 5.0000e-05
# Epoch 25/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - accuracy: 0.9432 - loss: 0.1795 - val_accuracy: 0.9470 - val_loss: 0.1428 - learning_rate: 5.0000e-05
# ✅ Fold 3 Accuracy: 0.9490
#
# 🟦 Fold 4/5
# Found 4077 validated image filenames belonging to 7 classes.
# Found 1019 validated image filenames belonging to 7 classes.
# Epoch 1/25
# /Users/simarkalsi/Projects/Soil k-cross/soilk/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 15s 105ms/step - accuracy: 0.6526 - loss: 1.0787 - val_accuracy: 0.1698 - val_loss: 1.7032 - learning_rate: 1.0000e-04
# Epoch 2/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.8589 - loss: 0.4428 - val_accuracy: 0.2875 - val_loss: 1.5863 - learning_rate: 1.0000e-04
# Epoch 3/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.8790 - loss: 0.3932 - val_accuracy: 0.6762 - val_loss: 0.8738 - learning_rate: 1.0000e-04
# Epoch 4/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.8859 - loss: 0.3181 - val_accuracy: 0.8518 - val_loss: 0.4152 - learning_rate: 1.0000e-04
# Epoch 5/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9072 - loss: 0.2893 - val_accuracy: 0.8960 - val_loss: 0.2786 - learning_rate: 1.0000e-04
# Epoch 6/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.9039 - loss: 0.2937 - val_accuracy: 0.9176 - val_loss: 0.2141 - learning_rate: 1.0000e-04
# Epoch 7/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9001 - loss: 0.2917 - val_accuracy: 0.9254 - val_loss: 0.1900 - learning_rate: 1.0000e-04
# Epoch 8/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9194 - loss: 0.2310 - val_accuracy: 0.9352 - val_loss: 0.1894 - learning_rate: 1.0000e-04
# Epoch 9/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9069 - loss: 0.2877 - val_accuracy: 0.9362 - val_loss: 0.1870 - learning_rate: 1.0000e-04
# Epoch 10/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9130 - loss: 0.2645 - val_accuracy: 0.9235 - val_loss: 0.1838 - learning_rate: 1.0000e-04
# Epoch 11/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.9143 - loss: 0.2547 - val_accuracy: 0.9284 - val_loss: 0.2029 - learning_rate: 1.0000e-04
# Epoch 12/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.9148 - loss: 0.2524 - val_accuracy: 0.9254 - val_loss: 0.1858 - learning_rate: 1.0000e-04
# Epoch 13/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9188 - loss: 0.2446 - val_accuracy: 0.9235 - val_loss: 0.1989 - learning_rate: 1.0000e-04
# Epoch 14/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.9248 - loss: 0.2211 - val_accuracy: 0.9333 - val_loss: 0.1655 - learning_rate: 5.0000e-05
# Epoch 15/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9321 - loss: 0.2278 - val_accuracy: 0.9323 - val_loss: 0.1660 - learning_rate: 5.0000e-05
# Epoch 16/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9287 - loss: 0.2100 - val_accuracy: 0.9401 - val_loss: 0.1581 - learning_rate: 5.0000e-05
# Epoch 17/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9225 - loss: 0.2172 - val_accuracy: 0.9372 - val_loss: 0.1785 - learning_rate: 5.0000e-05
# Epoch 18/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9312 - loss: 0.2089 - val_accuracy: 0.9382 - val_loss: 0.1560 - learning_rate: 5.0000e-05
# Epoch 19/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.9272 - loss: 0.2141 - val_accuracy: 0.9372 - val_loss: 0.1479 - learning_rate: 5.0000e-05
# Epoch 20/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9329 - loss: 0.2190 - val_accuracy: 0.9293 - val_loss: 0.1769 - learning_rate: 5.0000e-05
# Epoch 21/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.9378 - loss: 0.1904 - val_accuracy: 0.9421 - val_loss: 0.1675 - learning_rate: 5.0000e-05
# Epoch 22/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.9398 - loss: 0.1816 - val_accuracy: 0.9450 - val_loss: 0.1390 - learning_rate: 5.0000e-05
# Epoch 23/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9399 - loss: 0.1759 - val_accuracy: 0.9431 - val_loss: 0.1545 - learning_rate: 5.0000e-05
# Epoch 24/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.9290 - loss: 0.2178 - val_accuracy: 0.9421 - val_loss: 0.1523 - learning_rate: 5.0000e-05
# Epoch 25/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9421 - loss: 0.1807 - val_accuracy: 0.9401 - val_loss: 0.1412 - learning_rate: 5.0000e-05
# ✅ Fold 4 Accuracy: 0.9450
#
# 🟦 Fold 5/5
# Found 4077 validated image filenames belonging to 7 classes.
# Found 1019 validated image filenames belonging to 7 classes.
# Epoch 1/25
# /Users/simarkalsi/Projects/Soil k-cross/soilk/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 15s 106ms/step - accuracy: 0.6229 - loss: 1.2243 - val_accuracy: 0.3798 - val_loss: 1.7760 - learning_rate: 1.0000e-04
# Epoch 2/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.8537 - loss: 0.4741 - val_accuracy: 0.6173 - val_loss: 1.2556 - learning_rate: 1.0000e-04
# Epoch 3/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.8627 - loss: 0.3910 - val_accuracy: 0.8400 - val_loss: 0.6156 - learning_rate: 1.0000e-04
# Epoch 4/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.8799 - loss: 0.3697 - val_accuracy: 0.8548 - val_loss: 0.3742 - learning_rate: 1.0000e-04
# Epoch 5/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.8855 - loss: 0.3452 - val_accuracy: 0.9176 - val_loss: 0.2350 - learning_rate: 1.0000e-04
# Epoch 6/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9012 - loss: 0.3072 - val_accuracy: 0.9097 - val_loss: 0.2499 - learning_rate: 1.0000e-04
# Epoch 7/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9018 - loss: 0.3089 - val_accuracy: 0.9087 - val_loss: 0.2822 - learning_rate: 1.0000e-04
# Epoch 8/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9050 - loss: 0.2666 - val_accuracy: 0.9333 - val_loss: 0.1929 - learning_rate: 1.0000e-04
# Epoch 9/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9058 - loss: 0.2859 - val_accuracy: 0.9205 - val_loss: 0.2372 - learning_rate: 1.0000e-04
# Epoch 10/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9205 - loss: 0.2414 - val_accuracy: 0.9333 - val_loss: 0.2127 - learning_rate: 1.0000e-04
# Epoch 11/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9095 - loss: 0.2782 - val_accuracy: 0.9333 - val_loss: 0.1885 - learning_rate: 1.0000e-04
# Epoch 12/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9272 - loss: 0.2213 - val_accuracy: 0.9303 - val_loss: 0.1998 - learning_rate: 1.0000e-04
# Epoch 13/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9113 - loss: 0.2712 - val_accuracy: 0.9028 - val_loss: 0.3075 - learning_rate: 1.0000e-04
# Epoch 14/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9203 - loss: 0.2402 - val_accuracy: 0.9195 - val_loss: 0.2520 - learning_rate: 1.0000e-04
# Epoch 15/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9258 - loss: 0.2168 - val_accuracy: 0.9480 - val_loss: 0.1794 - learning_rate: 5.0000e-05
# Epoch 16/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 104ms/step - accuracy: 0.9294 - loss: 0.2054 - val_accuracy: 0.9372 - val_loss: 0.1753 - learning_rate: 5.0000e-05
# Epoch 17/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9213 - loss: 0.2284 - val_accuracy: 0.9352 - val_loss: 0.1832 - learning_rate: 5.0000e-05
# Epoch 18/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9236 - loss: 0.2259 - val_accuracy: 0.9411 - val_loss: 0.1735 - learning_rate: 5.0000e-05
# Epoch 19/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9300 - loss: 0.2090 - val_accuracy: 0.9431 - val_loss: 0.1788 - learning_rate: 5.0000e-05
# Epoch 20/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9246 - loss: 0.2320 - val_accuracy: 0.9450 - val_loss: 0.1828 - learning_rate: 5.0000e-05
# Epoch 21/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9407 - loss: 0.1886 - val_accuracy: 0.9392 - val_loss: 0.1850 - learning_rate: 5.0000e-05
# Epoch 22/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9371 - loss: 0.1906 - val_accuracy: 0.9382 - val_loss: 0.1892 - learning_rate: 2.5000e-05
# Epoch 23/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9320 - loss: 0.2026 - val_accuracy: 0.9421 - val_loss: 0.1694 - learning_rate: 2.5000e-05
# Epoch 24/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9300 - loss: 0.2117 - val_accuracy: 0.9450 - val_loss: 0.1636 - learning_rate: 2.5000e-05
# Epoch 25/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.9375 - loss: 0.1800 - val_accuracy: 0.9441 - val_loss: 0.1718 - learning_rate: 2.5000e-05
# ✅ Fold 5 Accuracy: 0.9450
#
# 📊 5-Fold Validation Accuracy: 0.9482 ± 0.0027

# %%
model.save(f"cnn_fold{fold+1}_CyAUG.keras")

# %%
import pickle
with open(f"history_fold{fold+1}_CyAUG.pkl", "wb") as f:
    pickle.dump(history.history, f)

# %%
def analyze_overfitting(histories):
    print("\n📉 Overfitting/Underfitting Analysis")
    for i, hist in enumerate(histories):
        acc = hist['accuracy']
        val_acc = hist['val_accuracy']
        loss = hist['loss']
        val_loss = hist['val_loss']
        
        acc_gap = val_acc[-1] - acc[-1]
        loss_gap = val_loss[-1] - loss[-1]

        print(f"Fold {i+1}:")
        if val_acc[-1] < acc[-1] - 0.05 and val_loss[-1] > loss[-1] + 0.2:
            print("  ⚠️  Likely Overfitting")
        elif val_acc[-1] < 0.7 and acc[-1] < 0.7:
            print("  🔍 Likely Underfitting")
        else:
            print("  ✅ Balanced Learning")
        print(f"  Final Acc: Train={acc[-1]:.4f}, Val={val_acc[-1]:.4f} | Loss: Train={loss[-1]:.4f}, Val={val_loss[-1]:.4f}")

# %%
analyze_overfitting(fold_histories)
# Out:
# 📉 Overfitting/Underfitting Analysis
# Fold 1:
#   ✅ Balanced Learning
#   Final Acc: Train=0.9281, Val=0.9363 | Loss: Train=0.2085, Val=0.1766
# Fold 2:
#   ✅ Balanced Learning
#   Final Acc: Train=0.9222, Val=0.9509 | Loss: Train=0.2117, Val=0.1713
# Fold 3:
#   ✅ Balanced Learning
#   Final Acc: Train=0.9370, Val=0.9470 | Loss: Train=0.1949, Val=0.1428
# Fold 4:
#   ✅ Balanced Learning
#   Final Acc: Train=0.9340, Val=0.9401 | Loss: Train=0.1982, Val=0.1412
# Fold 5:
#   ✅ Balanced Learning
#   Final Acc: Train=0.9343, Val=0.9441 | Loss: Train=0.1876, Val=0.1718

# %%
def plot_accuracy_loss(histories):
    fig, axs = plt.subplots(1, 2, figsize=(14, 5))

    for i, history in enumerate(histories):
        axs[0].plot(history['accuracy'], label=f'Train Fold {i+1}')
        axs[0].plot(history['val_accuracy'], linestyle='--', label=f'Val Fold {i+1}')
        axs[1].plot(history['loss'], label=f'Train Fold {i+1}')
        axs[1].plot(history['val_loss'], linestyle='--', label=f'Val Fold {i+1}')

    axs[0].set_title('Training vs Validation Accuracy (All Folds)')
    axs[0].set_xlabel('Epochs')
    axs[0].set_ylabel('Accuracy')
    axs[0].legend()
    axs[0].grid(True)

    axs[1].set_title('Training vs Validation Loss (All Folds)')
    axs[1].set_xlabel('Epochs')
    axs[1].set_ylabel('Loss')
    axs[1].legend()
    axs[1].grid(True)

    plt.tight_layout()
    plt.show()

# ✅ Call this after training all folds
plot_accuracy_loss(fold_histories)
